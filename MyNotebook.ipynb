# %% [markdown]
# <a href="https://colab.research.google.com/github/pttlinh1999/PythonSC0x/blob/main/MyNotebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The power of X

# %%
x=859
y=36
z=x+y

# %%
y=159

# %%
print(z)
# Out:
# 895

# %%
my_int=5
my_float=7.9
my_str='Hi There'
my_bool=True

# %%
print(type(my_float))
# Out:
# <class 'float'>

# %%
print(type(my_str))
# Out:
# <class 'str'>

# %%
a=my_int+my_float
print(a)
print(type(a))
# Out:
# 12.9
# <class 'float'>

# %%
print(my_int+my_str)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1756/2568037479.py in <cell line: 0>()
# ----> 1 print(my_int+my_str)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
y=7
y
# Out:
# 7

# %%
y
z=2

# %%
print(y)
z=2
# Out:
# 7

# %%
x=10
print(x*29)
# Out:
# 290

# %% [markdown]
# STRING

# %%
x='abc'
y='def'
z="""

ghi

"""
q='''

jkl

'''
print(x)
print(y)
print(z)
print(q)
# Out:
# abc
# def
#
#
# ghi
#
#
#
#
# jkl

# %%
x="She said \"hi\""
print(x)
# Out:
# She said "hi"

# %% [markdown]
# STRING FORMATTING
#
# Some of the more common ways include:
#
# '+ : String concatenation (combines strings together)
#
# f : F strings (substitues anything in {...} as the executed Python code it contains)
#
# format : Format (allows specifying variables in {...} that can be passed as arguments to be formatted)
#
# Occasionally, you might also see the old format method:
#
#  % : String interpolation

# %%
# Using concatenation
print("Hello"+' '+'World!')
# Out:
# Hello World!

# %%
# Using Format
print("Hello {answer}!".format(answer="World"))
# Out:
# Hello World!

# %%
# Using String Interpolation
print("Hello %s!" % 'World')
# Out:
# Hello World!

# %%
# Using F strings
animal='Fish'
print(f"Goodbye and thanks for all the {animal}!")
# Out:
# Goodbye and thanks for all the Fish!

# %% [markdown]
# OPERATORS
#
# Operators are processes that access and manipulate objects. In Python, there are many different built-in operators.
#
# Some common mathematical operators include:
#
# - `+`  : Addition
# - `-`  : Subtraction (or numeric negation)
# - `*`  : Multiplication
# - `/`  : Division
# - `**`  : Exponentiation
# - `//`  : Floor Division
# - `%` : Modulo

# %%
print(5+3)
# Out:
# 8

# %% [markdown]
# Some common mathematical operations include:
#
#  - int : Integer (remove decimals and make integer)
#
#  - round : Round to the nearest integer
#
# There are also string operators. Some common string operators include:
#
# - `+` : Concatenation.
#
# Some common logical operators include:
#
# - and : And
# - or : Or
# - not : Not (or boolean negation)

# %%
print(int(5.789))
print(int(-5.789))
print(round(5.789))
print(round(-5.789))
# Out:
# 5
# -5
# 6
# -6

# %%
print('True and False:', True and False)
print('True and True:', True and True)
print('True or False:', True or False)
print('False or False:', False or False)
print('not True:      ', not True)
print('not False:     ', not False)
# Out:
# True and False: False
# True and True: True
# True or False: True
# False or False: False
# not True:       False
# not False:      True

# %% [markdown]
# Some common comparison operators include:
#
#  - `<` : Is less than
#  - `<=` : Is less than or equal to
#  - `==` : Is equal to value (note that we don't use a single  `=`   sign here, because that's what you would use to assign a value to a variable!)
#  - `is` : Is equal to reference object
#  - `!=` : Is not equal to value
#  - `is not` : Is not equal to reference object
#  - `>` : Is greater than
#  - `>=` : Is greater than or equal to

# %%
print('5<6:           ', 5<6)
print('5<5:           ', 5<5)
print('5<=5:          ', 5<=5)
print('5==5:          ', 5==5)
print('5==5.0:        ', 5==5.0)
print('5 is 5.0:      ', 5 is 5.0)
print('5 is not 5.0:  ', 5 is not 5.0)
print('5!=5.0:        ', 5!=5.0)
print('6>5:           ', 6>5)
print('6>=5:          ', 6>=5)
# Out:
# 5<6:            True
# 5<5:            False
# 5<=5:           True
# 5==5:           True
# 5==5.0:         True
# 5 is 5.0:       False
# 5 is not 5.0:   True
# 5!=5.0:         False
# 6>5:            True
# 6>=5:           True
# <>:6: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:7: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# <>:6: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:7: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# /tmp/ipykernel_1107/799635676.py:6: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   print('5 is 5.0:      ', 5 is 5.0)
# /tmp/ipykernel_1107/799635676.py:7: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
#   print('5 is not 5.0:  ', 5 is not 5.0)

# %% [markdown]
# **DATA STRUCTURES - Lists and Dictionaries**
#
# Data structures offer ways to store and access more complex data. Some of the most used Python data structures include:
#
# - `list`: An ordered mutable (changeable) collection of elements
# - `dict`: A dictionary (or associative array) of key value pairs
#
# Other common data structures (that are not covered here) include:
#
# - `tuple`: An ordered immutable (unchangeable) collection of elements
# - `set`: An unordered immutable (unchangeable) collection of **unique** elements
#
# **LISTS**
#
# Lists offer a way to group together other Python values into a single value. A list is enclosed in brackets `[]` separated by commas.
#
# Lists are often comprised of items of the same type, but this is not a restriction.
#
# Lists have some helpful features. They can be indexed and sliced. You can access a specific item in the list by calling its index in a bracket. Note that Python uses a 0 based index system. This means that the index for the first item in the list will be zero.
#
# You can slice a list (cut it into parts) by using the slice notation of `[start:end]` where `start` is inclusive and `end` is exclusive.
#
# If you want to start your position based on numbers from the end of the list, you can use negative indexing.
#
# **NOTE:** Negative indexing is not 0 based. This means that -1 would equal the last item in the list.
#
# Lists can also be concatenated like strings.

# %%
x=['a','b','c','d','e']
print(x)
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
# Get the first item in the list specified as 'x' above
print(x[0])

# Get the first 3 (positions 0, 1 and 2) elements in the list
print(x[:3])

# Get all elements from positions 2 on (positions 2, 3 and 4) elements in the list
print(x[2:])

# Get the elements from position 1 to position 3 in the list
print(x[1:4])

# Get the last 3 elements in the list
print(x[-3:])

# Get everything except the last 2 items in the list
print(x[:-2])
# Out:
# a
# ['a', 'b', 'c']
# ['c', 'd', 'e']
# ['b', 'c', 'd']
# ['c', 'd', 'e']
# ['a', 'b', 'c']

# %%
y=[1,2,3]
z=[4,5,6]
print(y+z)
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# Since lists are mutable, you can actively change their content on the fly. You can do this by combining indexing and assignment.
#
# You can also add to lists as you need using concatenation  `+` (to merge to lists) or appending `.append(<item>)` new items directly to the end of the list.

# %%
q=['apple', 'banana', 'pear']
print(q)
q[0]='peach'
print(q)
# Out:
# ['apple', 'banana', 'pear']
# ['peach', 'banana', 'pear']

# %%
r=['a','b','c','d']
print(r)
# Replace positions 1 and 2 with m and n
r[1:3]=['m','n']
print(r)
# Out:
# ['a', 'b', 'c', 'd']
# ['a', 'm', 'n', 'd']

# %%
s=[1,2,3]
s.append(4)
print(s)
t=[5]
s+=t
# The above statement is an in place statement
# It is equivalent to 's = s+t'
print(s)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4, 5]

# %% [markdown]
# **DICTIONARY**
#
# Dictionaries offer a way to group key value pairs into a cohesive and easily accessable element. A dictionary is enclosed in curley brackets  `{}`  and is composed of  `key:value`  pairs separated by a comma where `keys can be any immutable data type` such as string or a number, and values represent any type of element.

# %%
translate_hi={
      'spanish': 'hola',
      'chinese': 'nihao',
      'german': 'hallo'
}

# %% [markdown]
# The values in the dictionary can be accessed by calling their respective keys.

# %%
print(translate_hi['spanish'])

# %% [markdown]
# Occasionally, you might not be sure if a key is in a dictionary. If the key you are calling is not in the dictionary, using it as an index value will cause an error:

# %%
print(translate_hi['dutch'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1107/1788567367.py in <cell line: 0>()
# ----> 1 print(translate_hi['dutch'])
#
# KeyError: 'dutch'

# %% [markdown]
# If you want to provide a default value to be used when a dictionary key is not present, you can use the  `get` method.

# %%
print(translate_hi.get('german','Translation Not Found'))
# Out:
# hallo

# %%
print(translate_hi.get('dutch','Translation Not Found'))
# Out:
# Translation Not Found

# %% [markdown]
# Dictionaries are mutable (changeable). Once you have a dictionary, you can add values by using index assignment, or remove values using the  `del`  statement.

# %%
y={
      'a':1,
      'b':2,
      'c':3,
}
print(y)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
# Assign a new key of 'd' with a value of '4'
y['d']=4
print(y)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
# Remove the key 'a'
del y['a']
print(y)
# Out:
# {'b': 2, 'c': 3, 'd': 4}

# %% [markdown]
# **DATA STRUCTURE FUNCTIONS**
#
# To help with data structures, Python has a variety of built in functions that can help simplify code. Some common `mathematical functions` for lists include:
#
# - `sum`: The sum of a list of numbers
# - `min`: The minimum of a list of numbers
# - `max`: The maximum of a list of numbers
#
# Dictionaries also come with some additional functions to translate them into lists for usability.
#
# Some of the common functions (more specifically, methods attached to dictionaries) to convert dictionaries into lists include:
#
# - `values()` : Get the values as a list
# - `keys()` : Get the keys as a list
# - `items()` : Get a list of key value pairs as a tuple
#
# **Note**: You will notice that the lists above are not exactly lists, but rather special iterable objects (that are very similar to lists).
#
# If for some reason, you need a list object, they can be converted into lists using the `list` function.

# %%
x=[1,2,3,4,5]
print(sum(x))
print(min(x))
print(max(x))
# Out:
# 15
# 1
# 5

# %%
y={
    'a':1,
    'b':2,
    'c':3
}

# Get the keys
print(y.keys())

# Get the value
print(y.values())

# Get the sum of values
print(sum(y.values()))

# Get the items as a list of key value pair tuples
print(y.items())

# Get the list object which are converted into list using the list funtion
print(list(y.keys()))
# Out:
# dict_keys(['a', 'b', 'c'])
# dict_values([1, 2, 3])
# 6
# dict_items([('a', 1), ('b', 2), ('c', 3)])
# ['a', 'b', 'c']

# %% [markdown]
# **LOOPING AND ITERATION**
#
# Looping and iteration are foundational parts of programming in Python. They allow you to access or modify items given an iterable entity. Iterable entities are, for example, lists, dictionaries, and tuples.
#
# **For and While Loops**
# Some of the common loop and iteration processes include:
#
# - `for` loops: Loop over an iteratable entity
# - `while` loops: Loop while a condition is met
#
# These loops start as a statement followed by a colon (`:`) and loop over all content indented (`4 spaces`) after the initial statement. The basic nomenclature is:
#
# for `<variable>` in `<iterator>`:
#     `<do something>`
#     `<do something else>
#     ...`
#
# `<code that runs after loop>`
#
# **NOTE:** Python officially recommends 4 spaces for indentation style, however, Google recommends 2. If you use two spaces, your code may work with Google products, but possibly not on other platforms. If you use 4 spaces, it should work on both.
#
# Loops allow creating a loop variable that is assigned each item in the iterable as the loop progresses.

# %%
for i in ['a','b','c']:
  print(i)

# This would be equivalent to:
print('a')
print('b')
print('c')
# Out:
# a
# b
# c
# a
# b
# c

# %%
for i in [1,2,3]:
  temp_item = i+1
  temp_item_squared = temp_item*2
  print(temp_item_squared)

print("Loop Finished")
# Out:
# 4
# 6
# 8
# Loop Finished

# %% [markdown]
# As for `while` loops, they operate very similar to  `for` loops, except they continue to loop while some conditional argument is satisfied. This requires some type of logical operator in the loop statement.
#
# This logical operator is tested after completing each iteration given the current variables in the runtime. Using this allows you edit variables as you go to check if a condition is met.

# %%
x=0
while x<5:
  # Add one to x in place
  # The below function is equivalent to `x=x+1`
  x+=1
  print(x)

print("Loop Finished")
# Out:
# 1
# 2
# 3
# 4
# 5
# Loop Finished

# %%
for i in range(1,5):
  print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
y={
    'a':1,
    'b':2,
    'c':3
}

for i in y.keys():
  print(i)
# Out:
# a
# b
# c

# %%
for i in y.values():
  print(i)
# Out:
# 1
# 2
# 3

# %% [markdown]
# If you are looping over a list of tuples, you can use positional assignment to loop multiple variables at once.

# %%
data = [('a','z'),('b','y'),('c','z')]
for i,j in data:
  print('i',i)
  print('j',j)
# Out:
# i a
# j z
# i b
# j y
# i c
# j z

# %% [markdown]
# This can be very useful in certain circumstances. A very common circumstance where this is useful is looping over dictionary items.

# %%
y={
    'a':1,
    'b':2,
    'c':3
}
for key,value in y.items():
  print("key: ", key)
  print("value: ", value)
# Out:
# key:  a
# value:  1
# key:  b
# value:  2
# key:  c
# value:  3

# %% [markdown]
# **LIST COMPREHENSION**
#
# List comprehension allows you to create lists using iterators with minimal code.
#
# The basic syntax is:
#
# `[<statement> for <variable> in <iterator>]`

# %%
x=[i for i in range(5)]
print(x)
# Out:
# [0, 1, 2, 3, 4]

# %%
# This would be equivalent to
x=[]
for i in range (5):
  x.append(i)

print(x)
# Out:
# [0, 1, 2, 3, 4]

# %%
# Get the square numbers in a range
x=[i**2 for i in range (5)]
print(x)

# `**2` mean square root
# Out:
# [0, 1, 4, 9, 16]

# %% [markdown]
# List comprehensions also support if  statements. The basic syntax is:
#
# `[<statement> for <variable> in <iterator> if <condition>]`

# %%
# To collect only even numbers
# Remember that the `%` operator means modulo (or remainder after division)
# We only store numbers if the remainder of dividing by 2 is 0 or `i%2==0`

x=[i for i in range(5) if i%2==0]
print(x)

#`%2` chia hết cho 2
# Out:
# [0, 2, 4]

# %% [markdown]
# **FUNCTIONS**
#
# Functions in Python are used to execute a block of code when called. They can take in input arguments (parameters / inputs) and may or may not return an output variable.
#
# A function is defined using the `def` keyword.
#
# The basic nomenclature for functions is:
#
# `def <function name>(<input_1>, ..., <input_n>):
#     <do something>
#     <do something else>
#     return <some return value>`
#
# Functions are called with the following nomenclature:
#
# `<function name>(<input_1>, ..., <input_n>)`

# %%
# A simple function to square any input number would look like:

def square(x):
  return x**2

square(3)
# Out:
# 9

# %% [markdown]
# Function inputs can be given as **positional arguments** or as **keyword arguments**.
#
# In the example above, the  `square` function is called using a provided first positional argument of 3. When calling the function, the input value of `x` can be directly specified to remove ambiguity.

# %%
# To call the square function with a keyword argument:

square(x=4)
# Out:
# 16

# %%
# Functions can take in `n` arguments and have n lines of contents

def power(x,y):
  answer = x**y
  return answer


power(3,4)
# Out:
# 81

# %% [markdown]
# Positional arguments must be in the same order as the arguments specified in the function definition, while keyword arguments are assigned to a specific argument. In the `power`  function above, you would not be able to give `y` as a positional argument and x  as a keyword argument.
#
# NOTE: In Python, positional arguments must always precede keyword arguments when defining and calling functions.

# %%
power(4,x=3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2185/2211094413.py in <cell line: 0>()
# ----> 1 power(4,x=3)
#
# TypeError: power() got multiple values for argument 'x'

# %%
# Keyword arguments, however, can be called in any order if all arguments are passed using keywords
power(y=4,x=3)
# Out:
# 25

# %% [markdown]
# Input arguments can be given default values when defining a function. Arguments with default values must come after arguments without a default value.
#
# When a default value is provided, the function will use this value when the keyword argument is not provided.

# %%
# Notice how the default value of y is 2
# If not provided when the function is called, y will be 2
def multiply(x,y=2):
  return x*y

multiply(3)
# Out:
# 6

# %%
multiply(x=3,y=4)
# Out:
# 12

# %% [markdown]
# **PIP**
#
# Pip is the canonical Python package installer. It is used to easily install external packages. In general, `pip`  should be executed from a terminal on your machine to install packages. In the case of google colab, you can directly install packages using the same nomenclature.
#
# `pip install <package>`

# %%
pip install scx
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.4/20.4 MB 46.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 71.2 MB/s eta 0:00:00
# ...
#   Created wheel for type_enforced: filename=type_enforced-2.9.0-cp313-cp313-linux_x86_64.whl size=88679 sha256=142f43852557bf82439de344be4d8116cc7b938ca1983e3fd8124b117d0a1f3d
#   Stored in directory: /root/.cache/pip/wheels/19/56/e4/060d94f9eecc6a6ae66b0be10333595a0b1bb23d5a6fb4adcd
# Successfully built type_enforced
# ...
#   Attempting uninstall: PuLP
#     Found existing installation: PuLP 3.3.2
#     Uninstalling PuLP-3.3.2:
#       Successfully uninstalled PuLP-3.3.2
#   Attempting uninstall: duckdb
#     Found existing installation: duckdb 1.3.2
#     Uninstalling duckdb-1.3.2:
#       Successfully uninstalled duckdb-1.3.2
# ...

# %%
import scx

# %%
from scx.optimize import Model

# Create variables
product_1_amt = Model.variable(name="product_1", lowBound=0)
product_2_amt = Model.variable(name="product_2", lowBound=0)

# Initialize the model
my_model = Model(name="Generic_Problem", sense='maximize')

# Add the Objective Fn
my_model.add_objective(
    fn = (product_1_amt*1)+(product_2_amt*1)
)

# Add Constraints
my_model.add_constraint(
    name = 'input_1_constraint',
    fn = product_1_amt*1+product_2_amt*2 <= 100
)
my_model.add_constraint(
    name = 'input_2_constraint',
    fn = product_1_amt*3+product_2_amt*1 <= 200
)

# Solve the model
my_model.solve(get_duals=True, get_slacks=True)

# Show the outputs
# NOTE: outputs can be fetched directly as a dictionary with `my_model.get_outputs()`
my_model.show_outputs()
# Out:
# {'duals': {'input_1_constraint': 0.4, 'input_2_constraint': 0.2},
#  'objective': 80.0,
#  'slacks': {'input_1_constraint': -0.0, 'input_2_constraint': -0.0},
#  'status': 'Optimal',
#  'variables': {'product_1': 60.0, 'product_2': 20.0}}
